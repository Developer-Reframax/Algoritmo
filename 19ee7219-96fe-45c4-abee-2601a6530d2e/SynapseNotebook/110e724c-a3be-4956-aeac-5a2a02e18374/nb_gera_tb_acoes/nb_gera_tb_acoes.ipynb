# %%
# ==========================
# Importações
# ==========================
# %pip install requests  # (ative se necessário no Fabric)
import time
import requests
from typing import List, Dict

from pyspark.sql import Row
from pyspark.sql import types as T

# ==========================
# 1) Parâmetros
# ==========================
SUPABASE_TABLE = "tb_acoes"
SUPABASE_URL = f"https://jewtbymqxxubjpwnjtux.supabase.co/rest/v1/{SUPABASE_TABLE}"

# Mesmas chaves (em produção, use Key Vault / credenciais do Fabric)
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTU3NzQ1ODQsImV4cCI6MjAzMTM1MDU4NH0.bs8NXsld5F98WdGTqt_9U0d1HY3DSXT4us0Ur1Rs8HE"
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxNTc3NDU4NCwiZXhwIjoyMDMxMzUwNTg0fQ.qJW13vrpLiF_uIHpGxNCy0iGpr--WhUK8g-AfeS4xm8"

# Lakehouse destino (ajuste para o seu workspace/lakehouse)
path_destino = "abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_acoes"

# (Opcional) tabela gerenciada (catálogo). Deixe vazio para usar apenas o path físico.
tabela_destino = ""  # ex.: "bronze.tb_acoes"

# Coleta
PAGE_SIZE = 1000
HTTP_TIMEOUT = 60  # s

# ==========================
# 2) Schema explícito (tudo string)
# ==========================
schema = T.StructType([
    T.StructField("id", T.StringType(), True),
    T.StructField("created_at", T.StringType(), True),
    T.StructField("origem", T.StringType(), True),
    T.StructField("oque", T.StringType(), True),
    T.StructField("quem", T.StringType(), True),
    T.StructField("telefone_quem", T.StringType(), True),
    T.StructField("quando", T.StringType(), True),
    T.StructField("status", T.StringType(), True),
    T.StructField("obra_user", T.StringType(), True),
    T.StructField("criado_por", T.StringType(), True),
    T.StructField("modificado_por", T.StringType(), True),
    T.StructField("modificado_quando", T.StringType(), True),
    T.StructField("uuid_origem", T.StringType(), True),
    T.StructField("potencial", T.StringType(), True),
    T.StructField("observacoes", T.StringType(), True),
    T.StructField("etapa_processo", T.StringType(), True),
    T.StructField("responsavel_etapa", T.StringType(), True),
    T.StructField("verifica_eficacia", T.StringType(), True),
    T.StructField("eficaz", T.StringType(), True),
    T.StructField("responsavel_verificacao_eficacia", T.StringType(), True),
    T.StructField("prazo_verifica", T.StringType(), True),
    T.StructField("como", T.StringType(), True),
    T.StructField("local", T.StringType(), True),
    T.StructField("id_resp", T.StringType(), True),
])
cols = [f.name for f in schema]

# ==========================
# 3) Função GET com retry/backoff
# ==========================
def http_get_with_retry(url: str, headers: Dict[str, str], timeout: int, max_retries: int = 5) -> requests.Response:
    backoff = 1.5
    attempt = 0
    while True:
        try:
            resp = requests.get(url, headers=headers, timeout=timeout)
            if resp.status_code in (429, 500, 502, 503, 504):
                attempt += 1
                if attempt > max_retries:
                    resp.raise_for_status()
                time.sleep(backoff ** attempt)
                continue
            resp.raise_for_status()
            return resp
        except requests.RequestException:
            attempt += 1
            if attempt > max_retries:
                raise
            time.sleep(backoff ** attempt)

# ==========================
# 4) Coleta paginada no Supabase
# ==========================
base_headers = {
    "apikey": API_KEY,
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "Accept": "application/json",
}

offset = 0
registros: List[Dict] = []

while True:
    headers = {**base_headers, "Range": f"{offset}-{offset + PAGE_SIZE - 1}"}
    resp = http_get_with_retry(SUPABASE_URL, headers, timeout=HTTP_TIMEOUT)
    batch = resp.json()
    if not batch:
        break
    registros.extend(batch)
    if len(batch) < PAGE_SIZE:
        break
    offset += PAGE_SIZE

print(f"Registros coletados do Supabase ({SUPABASE_TABLE}): {len(registros)}")

# ==========================
# 5) Monta DataFrame sem inferência de tipos
# ==========================
if len(registros) == 0:
    df = spark.createDataFrame([], schema)
else:
    rows = []
    for rec in registros:
        fixed = {c: (None if rec.get(c) is None else str(rec.get(c))) for c in cols}
        rows.append(Row(**fixed))
    df = spark.createDataFrame(rows, schema)

df.printSchema()
df.show(10, truncate=False)

# ==========================
# 6) Escrita em Delta
# ==========================
if tabela_destino.strip():
    spark.sql(f"DROP TABLE IF EXISTS {tabela_destino}")
    df.write.format("delta").mode("overwrite").saveAsTable(tabela_destino)
    print(f"Tabela gerenciada gravada: {tabela_destino}")
else:
    df.write.format("delta").mode("overwrite").save(path_destino)
    print(f"Delta gravado no caminho: {path_destino}")

print(f"Linhas salvas: {df.count()}")
# Out:
# StatementMeta(, bc097f59-5a08-40ae-8ee4-9044d4d51a40, 3, Finished, Available, Finished)
# Registros coletados do Supabase (tb_acoes): 2271
# root
#  |-- id: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- origem: string (nullable = true)
#  |-- oque: string (nullable = true)
#  |-- quem: string (nullable = true)
#  |-- telefone_quem: string (nullable = true)
#  |-- quando: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- obra_user: string (nullable = true)
#  |-- criado_por: string (nullable = true)
#  |-- modificado_por: string (nullable = true)
#  |-- modificado_quando: string (nullable = true)
#  |-- uuid_origem: string (nullable = true)
#  |-- potencial: string (nullable = true)
#  |-- observacoes: string (nullable = true)
#  |-- etapa_processo: string (nullable = true)
#  |-- responsavel_etapa: string (nullable = true)
#  |-- verifica_eficacia: string (nullable = true)
#  |-- eficaz: string (nullable = true)
#  |-- responsavel_verificacao_eficacia: string (nullable = true)
#  |-- prazo_verifica: string (nullable = true)
#  |-- como: string (nullable = true)
#  |-- local: string (nullable = true)
#  |-- id_resp: string (nullable = true)
#
# +----+--------------------------------+------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+-------------+-------------------+------------+---------+-------------------------------+-------------------------------+-----------------------+------------------------------------+-----------------+------------------------------+-------------------------------+-------------------------------+-----------------+------+--------------------------------+--------------------------+------------------------------------------------------+----------------------+-------+
# |id  |created_at                      |origem                                    |oque                                                                                                                                   |quem                           |telefone_quem|quando             |status      |obra_user|criado_por                     |modificado_por                 |modificado_quando      |uuid_origem                         |potencial        |observacoes                   |etapa_processo                 |responsavel_etapa              |verifica_eficacia|eficaz|responsavel_verificacao_eficacia|prazo_verifica            |como                                                  |local                 |id_resp|
# +----+--------------------------------+------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------