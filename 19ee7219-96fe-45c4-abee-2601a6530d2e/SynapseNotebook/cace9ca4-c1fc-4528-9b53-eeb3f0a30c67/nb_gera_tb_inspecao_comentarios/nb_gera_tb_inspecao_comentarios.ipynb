# %%
# ==========================
# Importações
# ==========================
# %pip install requests  # (ative se necessário no Fabric)
import time
import requests
from typing import List, Dict

from pyspark.sql import Row
from pyspark.sql import types as T

# ==========================
# 1) Parâmetros
# ==========================
SUPABASE_TABLE = "tb_inspecao_comentarios"
SUPABASE_URL = f"https://jewtbymqxxubjpwnjtux.supabase.co/rest/v1/{SUPABASE_TABLE}"

# Mesmas chaves (em produção, use Key Vault / credenciais do Fabric)
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTU3NzQ1ODQsImV4cCI6MjAzMTM1MDU4NH0.bs8NXsld5F98WdGTqt_9U0d1HY3DSXT4us0Ur1Rs8HE"
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxNTc3NDU4NCwiZXhwIjoyMDMxMzUwNTg0fQ.qJW13vrpLiF_uIHpGxNCy0iGpr--WhUK8g-AfeS4xm8"

# Lakehouse destino (ajuste para o seu workspace/lakehouse)
path_destino = "abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_inspecao_comentarios"

# (Opcional) tabela gerenciada (catálogo). Deixe vazio para usar apenas o path físico.
tabela_destino = ""  # ex.: "bronze.tb_inspecao_comentarios"

# Config coleta
PAGE_SIZE = 1000
HTTP_TIMEOUT = 60  # s

# ==========================
# 2) Schema explícito (todos string)
# ==========================
schema = T.StructType([
    T.StructField("id", T.StringType(), True),
    T.StructField("created_at", T.StringType(), True),
    T.StructField("comentario", T.StringType(), True),
    T.StructField("uuid_inspecao", T.StringType(), True),
    T.StructField("id_resposta", T.StringType(), True),
])
cols = [f.name for f in schema]

# ==========================
# 3) Função GET com retry/backoff
# ==========================
def http_get_with_retry(url: str, headers: Dict[str, str], timeout: int, max_retries: int = 5) -> requests.Response:
    backoff = 1.5
    attempt = 0
    while True:
        try:
            resp = requests.get(url, headers=headers, timeout=timeout)
            if resp.status_code in (429, 500, 502, 503, 504):
                attempt += 1
                if attempt > max_retries:
                    resp.raise_for_status()
                time.sleep(backoff ** attempt)
                continue
            resp.raise_for_status()
            return resp
        except requests.RequestException:
            attempt += 1
            if attempt > max_retries:
                raise
            time.sleep(backoff ** attempt)

# ==========================
# 4) Coleta paginada no Supabase
# ==========================
base_headers = {
    "apikey": API_KEY,
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "Accept": "application/json",
}

offset = 0
registros: List[Dict] = []

while True:
    headers = {**base_headers, "Range": f"{offset}-{offset + PAGE_SIZE - 1}"}
    resp = http_get_with_retry(SUPABASE_URL, headers, timeout=HTTP_TIMEOUT)
    batch = resp.json()
    if not batch:
        break
    registros.extend(batch)
    if len(batch) < PAGE_SIZE:
        break
    offset += PAGE_SIZE

print(f"Registros coletados do Supabase ({SUPABASE_TABLE}): {len(registros)}")

# ==========================
# 5) Monta DataFrame sem inferência
# ==========================
if len(registros) == 0:
    df = spark.createDataFrame([], schema)
else:
    rows = []
    for rec in registros:
        fixed = {c: (None if rec.get(c) is None else str(rec.get(c))) for c in cols}
        rows.append(Row(**fixed))
    df = spark.createDataFrame(rows, schema)

df.printSchema()
df.show(10, truncate=False)

# ==========================
# 6) Escrita em Delta
# ==========================
if tabela_destino.strip():
    spark.sql(f"DROP TABLE IF EXISTS {tabela_destino}")
    df.write.format("delta").mode("overwrite").saveAsTable(tabela_destino)
    print(f"Tabela gerenciada gravada: {tabela_destino}")
else:
    df.write.format("delta").mode("overwrite").save(path_destino)
    print(f"Delta gravado no caminho: {path_destino}")

print(f"Linhas salvas: {df.count()}")
# Out:
# StatementMeta(, 383ea167-2248-456c-8ce8-141bd92136e4, 3, Finished, Available, Finished)
# Registros coletados do Supabase (tb_inspecao_comentarios): 37
# root
#  |-- id: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- comentario: string (nullable = true)
#  |-- uuid_inspecao: string (nullable = true)
#  |-- id_resposta: string (nullable = true)
#
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------+
# |id |created_at                      |comentario                                                                                                                                                                                                                |uuid_inspecao                       |id_resposta|
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------+
# |1  |2025-08-27T14:56:21.565589+00:00|comentario teste                                                                                                                                                                                                          |41c3970f-f498-4065-95e8-26846cc125a8|13561      |
# |2  |2025-08-29T15:14:11.198121+00:00|Operadores de ponte rolante possuem crachá de autorização para o mesmo                                                                                                                                                    |4e622b9e-58c9-4776-aa8d-3b81890e99d6|13844      |
# |3  |2025-08-29T16:02:46.997125+00:00|Foi orientado os colaboradores envolvidos a utilizar o suporte para elevar os cabos eletricos.                                                                                                                            |a73cbaf8-a5d7-481e-9988-abf472b7ce4e|13877      |
# |4  |2025-08-29T16:07:36.999341+00:00|Isolamento existe, porem precisa ser melhorado, pois existe isolamentos fixo quebrado no local.                                                                                                                           |a73cbaf8-a5d7-481e-9988-abf472b7ce4e|13888      |
# |5  |2025-08-29T16:16:10.101003+00:00|Foi orientado aos envolvidos para colocar os cabos eletricos no suportes de elevação.                                                                                                                                     |a73cbaf8-a5d7-481e-9988-abf472b7ce4e|13877      |
# |6  |2025-08-29T18:31:53.298154+00:00|Muitas tampas de canal com desnivel, outras tampas avermelhando precisando de nominimo um isolamento,  no local.                                                                                                          |9db7ad0b-18ca-421c-8aba-46cd581acc53|13947      |
# |7  |2025-08-29T18:35:38.721862+00:00|Local onde a maquina de demolição esta atuando esta com pouco isolamento, e tampas proximas abertas, deve ser melhorado o isolamento.                                                                                     |8190295f-f922-4775-b437-5ddb49861ab3|13948      |
# |8  |2025-08-29T18:38:21.929461+00:00|Muito residuo de demolição refrataria no local da atividade, ferramentas fora do lugar.                                                                                                                                   |8190295f-f922-4775-b437-5ddb49861ab3|13949      |
# |9  |2025-09-02T13:11:21.922142+00:00|durante a realização do check-list das anilhas foi identificado uma das anilhas danificada colaborador retirou a mesma da area e fez o descarte em local apropriado e colocou observação que aquela anilha foi descartada.|b9a0ee27-d524-4410-992f-bf86b2b07ce2|14420      |
# |10 |2025-09-02T13:15:18.452185+00:00|Realizado a limpeza e organização da area antes de iniciar as atividades de rotina devido area não esta limpa e organizada.                                                                                               |b9a0ee27-d524-4410-992f-bf86b2b07ce2|14438      |
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+-----------+
# only showing top 10 rows
#
# Delta gravado no caminho: abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_inspecao_comentarios
# Linhas salvas: 37
