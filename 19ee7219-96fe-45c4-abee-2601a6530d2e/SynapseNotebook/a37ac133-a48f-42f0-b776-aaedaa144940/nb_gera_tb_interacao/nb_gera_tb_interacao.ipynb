# %%
# ==========================
# Importações
# ==========================
# %pip install requests  # (ative se necessário no Fabric)
import time
import requests
from typing import List, Dict

from pyspark.sql import Row
from pyspark.sql import types as T

# ==========================
# 1) Parâmetros
# ==========================
SUPABASE_TABLE = "tb_interacao"
SUPABASE_URL = f"https://jewtbymqxxubjpwnjtux.supabase.co/rest/v1/{SUPABASE_TABLE}"

# Mesmas chaves (em produção, use Key Vault / credenciais do Fabric)
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTU3NzQ1ODQsImV4cCI6MjAzMTM1MDU4NH0.bs8NXsld5F98WdGTqt_9U0d1HY3DSXT4us0Ur1Rs8HE"
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxNTc3NDU4NCwiZXhwIjoyMDMxMzUwNTg0fQ.qJW13vrpLiF_uIHpGxNCy0iGpr--WhUK8g-AfeS4xm8"

# Lakehouse destino (ajuste para o seu workspace/lakehouse)
path_destino = "abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_interacao"

# (Opcional) tabela gerenciada (catálogo). Deixe vazio para usar apenas o path físico.
tabela_destino = ""  # ex.: "bronze.tb_interacao"

# Coleta
PAGE_SIZE = 1000
HTTP_TIMEOUT = 60  # s

# ==========================
# 2) Schema explícito (todos string)
# ==========================
schema = T.StructType([
    T.StructField("id", T.StringType(), True),
    T.StructField("created_at", T.StringType(), True),
    T.StructField("tipoInteracao", T.StringType(), True),
    T.StructField("metodoCoach", T.StringType(), True),
    T.StructField("data", T.StringType(), True),
    T.StructField("unidade", T.StringType(), True),
    T.StructField("empresa", T.StringType(), True),
    T.StructField("area", T.StringType(), True),
    T.StructField("local", T.StringType(), True),
    T.StructField("houveDesvio", T.StringType(), True),
    T.StructField("descricao", T.StringType(), True),
    T.StructField("acaoImediata", T.StringType(), True),
    T.StructField("evento", T.StringType(), True),
    T.StructField("houveViolacao", T.StringType(), True),
    T.StructField("instante", T.StringType(), True),
    T.StructField("grandesRiscos", T.StringType(), True),
    T.StructField("modificadoPor", T.StringType(), True),
    T.StructField("modificadoQuando", T.StringType(), True),
    T.StructField("mat_colaborador", T.StringType(), True),
    T.StructField("coordenador_responsavel", T.StringType(), True),
    T.StructField("classificacao", T.StringType(), True),
    T.StructField("contrato", T.StringType(), True),
    T.StructField("local_interacao", T.StringType(), True),
    T.StructField("supervisor_responsavel", T.StringType(), True),
])
cols = [f.name for f in schema]

# ==========================
# 3) Função GET com retry/backoff
# ==========================
def http_get_with_retry(url: str, headers: Dict[str, str], timeout: int, max_retries: int = 5) -> requests.Response:
    backoff = 1.5
    attempt = 0
    while True:
        try:
            resp = requests.get(url, headers=headers, timeout=timeout)
            if resp.status_code in (429, 500, 502, 503, 504):
                attempt += 1
                if attempt > max_retries:
                    resp.raise_for_status()
                time.sleep(backoff ** attempt)
                continue
            resp.raise_for_status()
            return resp
        except requests.RequestException:
            attempt += 1
            if attempt > max_retries:
                raise
            time.sleep(backoff ** attempt)

# ==========================
# 4) Coleta paginada no Supabase
# ==========================
base_headers = {
    "apikey": API_KEY,
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "Accept": "application/json",
}

offset = 0
registros: List[Dict] = []

while True:
    headers = {**base_headers, "Range": f"{offset}-{offset + PAGE_SIZE - 1}"}
    resp = http_get_with_retry(SUPABASE_URL, headers, timeout=HTTP_TIMEOUT)
    batch = resp.json()
    if not batch:
        break
    registros.extend(batch)
    if len(batch) < PAGE_SIZE:
        break
    offset += PAGE_SIZE

print(f"Registros coletados do Supabase ({SUPABASE_TABLE}): {len(registros)}")

# ==========================
# 5) Monta DataFrame sem inferência de tipos
# ==========================
if len(registros) == 0:
    df = spark.createDataFrame([], schema)
else:
    rows = []
    for rec in registros:
        fixed = {c: (None if rec.get(c) is None else str(rec.get(c))) for c in cols}
        rows.append(Row(**fixed))
    df = spark.createDataFrame(rows, schema)

df.printSchema()
df.show(10, truncate=False)

# ==========================
# 6) Escrita em Delta
# ==========================
if tabela_destino.strip():
    spark.sql(f"DROP TABLE IF EXISTS {tabela_destino}")
    df.write.format("delta").mode("overwrite").saveAsTable(tabela_destino)
    print(f"Tabela gerenciada gravada: {tabela_destino}")
else:
    df.write.format("delta").mode("overwrite").save(path_destino)
    print(f"Delta gravado no caminho: {path_destino}")

print(f"Linhas salvas: {df.count()}")
# Out:
# StatementMeta(, 59695c57-bcbb-4e42-8034-f3f49f382e2b, 3, Finished, Available, Finished)
# Registros coletados do Supabase (tb_interacao): 3036
# root
#  |-- id: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- tipoInteracao: string (nullable = true)
#  |-- metodoCoach: string (nullable = true)
#  |-- data: string (nullable = true)
#  |-- unidade: string (nullable = true)
#  |-- empresa: string (nullable = true)
#  |-- area: string (nullable = true)
#  |-- local: string (nullable = true)
#  |-- houveDesvio: string (nullable = true)
#  |-- descricao: string (nullable = true)
#  |-- acaoImediata: string (nullable = true)
#  |-- evento: string (nullable = true)
#  |-- houveViolacao: string (nullable = true)
#  |-- instante: string (nullable = true)
#  |-- grandesRiscos: string (nullable = true)
#  |-- modificadoPor: string (nullable = true)
#  |-- modificadoQuando: string (nullable = true)
#  |-- mat_colaborador: string (nullable = true)
#  |-- coordenador_responsavel: string (nullable = true)
#  |-- classificacao: string (nullable = true)
#  |-- contrato: string (nullable = true)
#  |-- local_interacao: string (nullable = true)
#  |-- supervisor_responsavel: string (nullable = true)
#
# +----+--------------------------------+----------------------------------+-----------+-------------------+----------------------------+--------+-----------------------------------------------------+---------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------+--------------------------+--------------------------+--------------------------------------+--------------------------+---------------+-------------------------+-------------------------------------+--------+---------------------------+----------------------------------+
# |id  |created_at                      |tipoInteracao                     |metodoCoach|data               |unidade                     |empresa |area                                                 |local                      |houveDesvio|descricao                                                                                                                                                                                            |acaoImediata                                                                                                      |evento|houveViolacao                                     |instante                  |grandesRiscos             |modificadoPor                         |modificadoQuando          |mat_colaborador|coordenador_responsavel  |classificacao                        |contrato|local_interacao            |supervisor_responsavel            |
# +----+--------------------------------+----------------------------------+-----------+-------------------+----------------------------+--------+-----------------------------------------------------+---------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------+--------------------------+--------------------------+--------------------------------------+--------------------------+---------------+-------------------------+-------------------------------------+--------+---------------------------+----------------------------------+
# |1925|2025-06-13T22:51:47.616742+00:00|Interação de Segurança - Empregado|sim        |2025-06-10T00:00:00|AMT - ArcelorMittal Tubarão |REFRAMAX|IGF - Gerência de Produção de Gusa                   |Granulador de escória (AMT)|Não        |colabores estavam realizando atividade na tubulação da alimentação do ge2 com toda a documentação correta e sem desvio                                                                               |foi abordado toda equipe e foi parabenizado pela preocupação com a segurança e o compromisso com zero acidente    |ROTINA|Não Houve Violação                                |NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |JERLLERSON NASCIMENTO DA SILVA BARRETO|2025-06-13T19:51:48.725005|129761         |CLAUDINO MAJDALANI LIMA  |SEM DESVIO                           |2078D   |GRANULADOR DE ESCÓRIA - AF1|JOHNNY HEINTZ DIAS                |
# |1934|2025-06-18T14:18:34.794446+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|NÃO        |2025-06-17T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |NÃO        |ACOMPANHADO OPERADOR NA ATIVIDADE DE PREVENTIVA DE EQUIPAMENTOSEM DESVIOS                                                                                                                            |VERIFICADO DOCUMENTAÇÃO E EPI NECESSARIOS PARA A ATIVIDADESEM DESVIOS                                             |ROTINA|NÃO HOUVE VIOLAÇÃO                                |NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |DANIEL DE ASSIS BARBOZA               |2025-06-18T11:18:34.624   |111014         |MARCIO DOS SANTOS        |SEM DESVIO                           |2002D   |OFICINA DE EMPILHADEIRA    |LUIZ FELIPE BENEZOLLI             |
# |1935|2025-06-18T14:26:34.228953+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-06-18T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |SIM        |REALIZADO UMA INTERAÇÃO DE SEGURANÇA NA ÁREA DO CAMBADOR E REALIZADO UM BATE PAPO COM OS COLABORADORESFOI DETECTADO QUE A MANGUEIRA DE USO PARA SANGRIA DOS VEIOS ESTAVA OFERECENDO RISCO DE TROPEÇAR|ORIENTADO OS COLABORADORESA MANTER A MANGUEIRA ENROLADA NO SUPORTE QUANDO NÃO ESTIVER EM USO                      |ROTINA|VIOLAÇÃO NÃO INTENCIONAL - DESCUIDO / ESQUECIMENTO|NENHUM INSTANTE ESPECÍFICO|ESCORREGAR, TROPEÇAR, CAIR|MARCOS FERREIRA SOUSA                 |2025-06-18T11:26:34.102   |86637          |EDSON GOMES DA SILVA     |ARRUMAÇÃO/LIMPEZA                    |2002D   |LINGOTAMENTO CONTINUO      |MARCOS FERREIRA SOUSA             |
# |1938|2025-06-19T09:31:35.595858+00:00|Interação de Segurança - Empregado|sim        |2025-06-18T00:00:00|AMT - ArcelorMittal Tubarão |REFRAMAX|IGF - Gerência de Produção de Gusa                   |Granulador de escória (AMT)|Não        |Foi realizado a interação com a equipe sobre percepção de risco da atividade                                                                                                                         |Foi abordado os principais riscos possíveis da atividade                                                          |ROTINA|Não Houve Violação                                |NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |VINICIUS DA SILVA SANTOS              |2025-06-19T06:31:34.68222 |136483         |CLAUDINO MAJDALANI LIMA  |SEM DESVIO                           |2078D   |GRANULADOR DE ESCÓRIA - AF1|JOHNNY HEINTZ DIAS                |
# |1983|2025-06-26T15:34:14.775413+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-06-26T00:00:00|AMT - ARCELORMITTAL TUBARÃO |AMT     |IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |NÃO        |REALIZADO UMA INTERAÇÃO DE SEGURANÇA COM O COLABORADOR DO EFETIVO PRÓPRIO AMT DURANTE A TROCA DO CALÇO DO DI N 35FOI NOTADO QUE O COLABORADOR ESTAVA UTILIZANDO ALGUMAS FERRAMENTAS DA ÁREA DO K7    |CONVERSADO COM O COLABORADOR POIS AS FERRAMENTAS SERIAM USADAS NAQUELE MOMENTO                                    |ROTINA|NÃO HOUVE VIOLAÇÃO                                |NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |MARCOS FERREIRA SOUSA                 |2025-06-26T12:34:14.541   |86637          |EDSON GOMES DA SILVA     |SEM DESVIO                           |2002D   |LINGOTAMENTO CONTINUO      |MARCOS FERREIRA SOUSA             |
# |2056|2025-07-01T15:22:38.647599+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-07-01T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |SIM        |DURANTE A CHEGAR AO ESCRITÓRIO O COLABORADOR ESTAVA ANDANDO UTILIZANDO FONE DE OUVIDO                                                                                                                |REALIZADA A INTERAÇÃO DE SEGURANÇA E COMUNICADO AO MESMO QUE É PROIBIDO TRANSITAR UTILIZADO FONE DE OUVIDO NA ÁREA|ROTINA|NÃO HOUVE VIOLAÇÃO                                |NENHUM INSTANTE ESPECÍFICO|ESCORREGAR, TROPEÇAR, CAIR|ANDERSON LUIZ PARANHA                 |2025-07-01T12:22:38.169   |138194         |MARCIO DOS SANTOS        |ADORNO                               |2002D   |PPC - REFRAMAX             |MILTON BARCELLOS FILHO            |
# |2077|2025-07-04T06:45:24.223497+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-07-03T00:00:00|AMT - ARCELORMITTAL TUBARÃO |        |IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |NÃO        |REALIZADO INTERAÇÃO DE SEGURANÇA COM OPERADOR DA ESCAVADEIRA  DO PÁTIO DO CAMBADO  CONFERIDO DOCUMENTAÇÃO ROTAS DE FULGA E PONTO DE ENCONTRO                                                         |OPERADOR ESTAVA COM DOCUMENTAÇÃO PREENCHIDA CONHECIA A ROTA DE FULGA E CONHECIA O PONTO DE ENCONTRO DA ÁREA       |ROTINA|NÃO HOUVE VIOLAÇÃO                                |INSPEÇÃO DE SEGURANÇA     |NENHUM ITEM ESPECÍFICO    |CARLOS ALEXANDRE OLIVEIRA PLACIDES    |2025-07-04T03:45:23.85    |88162          |EDSON GOMES DA SILVA     |DOCUMENTAÇÃO DE SEGURANÇA/OPERACIONAL|2002D   |LINGOTAMENTO CONTINUO      |CARLOS ALEXANDRE OLIVEIRA PLACIDES|
# |2102|2025-07-07T18:59:17.509846+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-07-07T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |SIM        |DURANTE ATIVIDADE DE ESMERILHAMENTO O COLABORADOR NÃO ULTILIZAVA PROTETOR FACIAL                                                                                                                     |REALIZADA A INTERAÇÃO E COMUNICADO A IMPORTÂNCIA DO USO DOS EPIS                                                  |ROTINA|NÃO HOUVE VIOLAÇÃO                                |NENHUM INSTANTE ESPECÍFICO|COMPRESSÃO, CORTE         |ANDERSON LUIZ PARANHA                 |2025-07-07T15:59:17.21    |138194         |MARCIO DOS SANTOS        |EPI                                  |2002D   |OFICINA DE K 7             |MILTON BARCELLOS FILHO            |
# |2125|2025-07-11T17:00:06.415207+00:00|INTERAÇÃO DE SEGURANÇA - EMPREGADO|NÃO        |2025-07-11T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IGF - GERÊNCIA DE PRODUÇÃO DE GUSA                   |ALTO-FORNO (AMT)           |SIM        |MECANICO DA AMT COM O BLUSÃO ABERTO E COM ABAFADOR DE CONCHA LEVANTADO NA AREA DO AF03                                                                                                               |FOI ABORDADO O MECANICO E ORIENTADO O MESMO A FECHAR O BLUSÃO E A UTILIZAÇÃO CORRETA DO ABAFADOR TIPO CONHA       |ROTINA|VIOLAÇÃO NÃO INTENCIONAL - DESCUIDO / ESQUECIMENTO|NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |BRAS VANILDO PUPIN                    |2025-07-11T14:00:06.315   |62357          |SIDNEY ROBSON DE OLIVEIRA|EPI                                  |2067D   |ALTO FORNO - 3             |BRAS VANILDO PUPIN                |
# |2127|2025-07-12T14:29:37.63956+00:00 |INTERAÇÃO DE SEGURANÇA - EMPREGADO|SIM        |2025-07-12T00:00:00|AMT - ARCELORMITTAL TUBARÃO |REFRAMAX|IXA - GERÊNCIA TÉCNICA DE PROCESSO DE PRODUÇÃO DE AÇO|ACIARIA (AMT)              |NÃO        |REALIZADO INTERAÇÃO DE SEGURANÇA COM OS SOLDADORES NA ATIVIDADE DE RECORTE DA BORDA DO DI N 35CONVERSADO SOBRE A ATIVIDADE E CHECADO AS DOCUMENTAÇÕES E NÃO ENCONTRADO ANORMALIDADE                  |SEM DESVIO                                                                                                        |ROTINA|NÃO HOUVE VIOLAÇÃO                                |NENHUM INSTANTE ESPECÍFICO|NENHUM ITEM ESPECÍFICO    |MARCOS FERREIRA SOUSA                 |2025-07-12T11:29:37.391   |86637          |EDSON GOMES DA SILVA     |SEM DESVIO                           |2002D   |LINGOTAMENTO CONTINUO      |MARCOS FERREIRA SOUSA             |
# +----+--------------------------------+----------------------------------+-----------+-------------------+----------------------------+--------+-----------------------------------------------------+---------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------+--------------------------+--------------------------+--------------------------------------+--------------------------+---------------+-------------------------+-------------------------------------+--------+---------------------------+----------------------------------+
# only showing top 10 rows
#
# Delta gravado no caminho: abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_interacao
# Linhas salvas: 3036
