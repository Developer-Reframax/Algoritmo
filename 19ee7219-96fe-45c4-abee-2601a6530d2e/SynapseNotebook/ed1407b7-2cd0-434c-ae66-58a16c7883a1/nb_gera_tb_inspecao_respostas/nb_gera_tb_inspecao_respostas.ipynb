# %%
# ==========================
# Importações
# ==========================
# %pip install requests  # (ative se necessário no Fabric)
import time
import requests
from typing import List, Dict

from pyspark.sql import Row
from pyspark.sql import types as T

# ==========================
# 1) Parâmetros
# ==========================
SUPABASE_TABLE = "tb_inspecao_respostas"
SUPABASE_URL = f"https://jewtbymqxxubjpwnjtux.supabase.co/rest/v1/{SUPABASE_TABLE}"

# Mesmas chaves (em produção, use Key Vault / credenciais do Fabric)
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTU3NzQ1ODQsImV4cCI6MjAzMTM1MDU4NH0.bs8NXsld5F98WdGTqt_9U0d1HY3DSXT4us0Ur1Rs8HE"
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxNTc3NDU4NCwiZXhwIjoyMDMxMzUwNTg0fQ.qJW13vrpLiF_uIHpGxNCy0iGpr--WhUK8g-AfeS4xm8"

# Lakehouse destino (ajuste para o seu workspace/lakehouse)
path_destino = "abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_inspecao_respostas"

# (Opcional) tabela gerenciada (catálogo). Deixe vazio para usar apenas o path físico.
tabela_destino = ""  # ex.: "bronze.tb_inspecao_respostas"

# Coleta
PAGE_SIZE = 1000
HTTP_TIMEOUT = 60  # s

# ==========================
# 2) Schema explícito (todos string)
# ==========================
schema = T.StructType([
    T.StructField("id", T.StringType(), True),
    T.StructField("created_at", T.StringType(), True),
    T.StructField("uuidorigemexecucao", T.StringType(), True),
    T.StructField("itemavaliado", T.StringType(), True),
    T.StructField("resposta", T.StringType(), True),
    T.StructField("desabilitana", T.StringType(), True),
])
cols = [f.name for f in schema]

# ==========================
# 3) Função GET com retry/backoff
# ==========================
def http_get_with_retry(url: str, headers: Dict[str, str], timeout: int, max_retries: int = 5) -> requests.Response:
    backoff = 1.5
    attempt = 0
    while True:
        try:
            resp = requests.get(url, headers=headers, timeout=timeout)
            if resp.status_code in (429, 500, 502, 503, 504):
                attempt += 1
                if attempt > max_retries:
                    resp.raise_for_status()
                time.sleep(backoff ** attempt)
                continue
            resp.raise_for_status()
            return resp
        except requests.RequestException:
            attempt += 1
            if attempt > max_retries:
                raise
            time.sleep(backoff ** attempt)

# ==========================
# 4) Coleta paginada no Supabase
# ==========================
base_headers = {
    "apikey": API_KEY,
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "Accept": "application/json",
}

offset = 0
registros: List[Dict] = []

while True:
    headers = {**base_headers, "Range": f"{offset}-{offset + PAGE_SIZE - 1}"}
    resp = http_get_with_retry(SUPABASE_URL, headers, timeout=HTTP_TIMEOUT)
    batch = resp.json()
    if not batch:
        break
    registros.extend(batch)
    if len(batch) < PAGE_SIZE:
        break
    offset += PAGE_SIZE

print(f"Registros coletados do Supabase ({SUPABASE_TABLE}): {len(registros)}")

# ==========================
# 5) Monta DataFrame sem inferência de tipos
# ==========================
if len(registros) == 0:
    df = spark.createDataFrame([], schema)
else:
    rows = []
    for rec in registros:
        fixed = {c: (None if rec.get(c) is None else str(rec.get(c))) for c in cols}
        rows.append(Row(**fixed))
    df = spark.createDataFrame(rows, schema)

df.printSchema()
df.show(10, truncate=False)

# ==========================
# 6) Escrita em Delta
# ==========================
if tabela_destino.strip():
    spark.sql(f"DROP TABLE IF EXISTS {tabela_destino}")
    df.write.format("delta").mode("overwrite").saveAsTable(tabela_destino)
    print(f"Tabela gerenciada gravada: {tabela_destino}")
else:
    df.write.format("delta").mode("overwrite").save(path_destino)
    print(f"Delta gravado no caminho: {path_destino}")

print(f"Linhas salvas: {df.count()}")
# Out:
# StatementMeta(, d18438f1-f2ec-4f27-b719-52ffced12216, 3, Finished, Available, Finished)
# Registros coletados do Supabase (tb_inspecao_respostas): 11913
# root
#  |-- id: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- uuidorigemexecucao: string (nullable = true)
#  |-- itemavaliado: string (nullable = true)
#  |-- resposta: string (nullable = true)
#  |-- desabilitana: string (nullable = true)
#
# +-----+--------------------------------+------------------------------------+---------------------------------------------------------------------------------------------------------------------+-------------+------------+
# |id   |created_at                      |uuidorigemexecucao                  |itemavaliado                                                                                                         |resposta     |desabilitana|
# +-----+--------------------------------+------------------------------------+---------------------------------------------------------------------------------------------------------------------+-------------+------------+
# |15658|2025-09-12T12:49:32.741364+00:00|40e09119-781c-4cd8-9dda-d48cd5ee6f0a|1.28 - ISOLAMENTO DO PISO INFERIOR, REALIZADO? CONSIDERADO EFICAZ?                                                   |             |True        |
# |15626|2025-09-12T12:49:27.693489+00:00|40e09119-781c-4cd8-9dda-d48cd5ee6f0a|1.38 - OS MANÔMETROS DO CONJUNTO DE OXI-CORTE ESTÃO CALIBRADOS E POSSUEM ETIQUETA?                                   |Não conforme |True        |
# |18207|2025-09-30T18:44:13.768224+00:00|5952d983-179a-4ef0-a8ae-a06b34bea6f1|1.2 - OS ENVOLVIDOS NA ATIVIDADE TEM TREINAMENTO DE NR 33? APTO?                                                     |Não se aplica|True        |
# |18587|2025-10-02T19:48:12.79603+00:00 |9c970905-71d2-4950-ac23-8c853a348ca8|POSSUI CONTROLES PARA EVITAR A INTERAÇÃO HOMEM E MÁQUINAS?                                                           |             |False       |
# |18597|2025-10-02T19:48:14.179698+00:00|9c970905-71d2-4950-ac23-8c853a348ca8|AS LIXADEIRAS ELETRICAS POSSUEM O DISPOSITIVO HOMEM MORTO?                                                           |             |False       |
# |15678|2025-09-17T05:26:14.683022+00:00|99899f2f-b2f2-4e7f-9b28-939cbb31a162|1.2. OS COLABORADORES ESTÃO USANDO EPI CORRETAMENTE?                                                                 |Conforme     |True        |
# |15682|2025-09-17T05:26:15.281421+00:00|99899f2f-b2f2-4e7f-9b28-939cbb31a162|4.3. AS CONDIÇÕES DOS EQUIPAMENTOS/FERRAMENTAS ESTÃO CONDIZENTES COM O QUE FOI PREENCHIDO NO CHECK-LIST?             |Conforme     |True        |
# |15686|2025-09-17T05:26:15.772577+00:00|99899f2f-b2f2-4e7f-9b28-939cbb31a162|2.4. HÁ ALGUÉM TRABALHANDO COM MÁQUINAS, EQUIPAMENTOS OU FERRAMENTAS DE FORMA INCORRETA E COM RISCO DE SE ACIDENTAR ?|Conforme     |True        |
# |15689|2025-09-17T05:26:16.117229+00:00|99899f2f-b2f2-4e7f-9b28-939cbb31a162|4.2. OS EQUIPAMENTOS / FERRAMENTAS SÃO OS CORRETOS PARA O TRABALHO E O COLABORADOR ESTÁ USANDO CORRETAMENTE?         |Conforme     |True        |
# |12742|2025-08-22T13:27:33.961967+00:00|9a9bd5fd-06c0-4010-bb29-5fea47ce248d|1.4 - ESTÁ SENDO FEITO O CONTROLE DE ACESSO? ESTÁ EFICIENTE?                                                         |Não se aplica|True        |
# +-----+--------------------------------+------------------------------------+---------------------------------------------------------------------------------------------------------------------+-------------+------------+
# only showing top 10 rows
#
# Delta gravado no caminho: abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tb_inspecao_respostas
# Linhas salvas: 11913
