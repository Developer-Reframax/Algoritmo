# %%
# ==========================
# Importações
# ==========================
# %pip install requests  # (ative se necessário no Fabric)
import time
import requests
from typing import List, Dict

from pyspark.sql import Row
from pyspark.sql import types as T

# ==========================
# 1) Parâmetros
# ==========================
SUPABASE_TABLE = "tb_kaizen_cadastro"
SUPABASE_URL = f"https://jewtbymqxxubjpwnjtux.supabase.co/rest/v1/{SUPABASE_TABLE}"

# Mesmas chaves (em produção, use Key Vault / credenciais do Fabric)
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTU3NzQ1ODQsImV4cCI6MjAzMTM1MDU4NH0.bs8NXsld5F98WdGTqt_9U0d1HY3DSXT4us0Ur1Rs8HE"
BEARER_TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Impld3RieW1xeHh1Ympwd25qdHV4Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcxNTc3NDU4NCwiZXhwIjoyMDMxMzUwNTg0fQ.qJW13vrpLiF_uIHpGxNCy0iGpr--WhUK8g-AfeS4xm8"

# Lakehouse destino (ajuste para o seu workspace/lakehouse)
path_destino = "abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tab_boas_praticas"

# (Opcional) nome de tabela gerenciada (catálogo). Deixe vazio para usar apenas o path físico.
tabela_destino = ""  # ex.: "bronze.tb_kaizen_cadastro"

# Coleta
PAGE_SIZE = 1000
HTTP_TIMEOUT = 60  # s

# ==========================
# 2) Schema explícito
# ==========================
schema = T.StructType([
    T.StructField("id", T.LongType(), True),
    T.StructField("created_at", T.StringType(), True),
    T.StructField("objetivo", T.StringType(), True),
    T.StructField("area_aplicada", T.StringType(), True),
    T.StructField("data", T.StringType(), True),
    T.StructField("pilar", T.StringType(), True),
    T.StructField("elimina_desperdicio", T.StringType(), True),
    T.StructField("modificado_por", T.StringType(), True),
    T.StructField("modificado_quando", T.StringType(), True),
    T.StructField("contrato_user", T.StringType(), True),
    T.StructField("status", T.StringType(), True),
    T.StructField("relevancia", T.StringType(), True),
    T.StructField("uuidcadastro", T.StringType(), True),
    T.StructField("resultados", T.StringType(), True),
    T.StructField("geral", T.StringType(), True),
    T.StructField("responsavel_etapa", T.StringType(), True),
    T.StructField("visualizacoes", T.LongType(), True),
    T.StructField("votos", T.LongType(), True),
    T.StructField("categoria", T.StringType(), True),
    T.StructField("titulo", T.StringType(), True),
    T.StructField("descricao", T.StringType(), True),
    T.StructField("etapa_processo", T.StringType(), True),
    T.StructField("fabricou_dispositivo", T.StringType(), True),
    T.StructField("projeto", T.StringType(), True),
    T.StructField("nota_local", T.StringType(), True),
    T.StructField("nota_corporativo", T.StringType(), True),
    T.StructField("premiada", T.StringType(), True),
    T.StructField("reconhecida", T.StringType(), True),
    T.StructField("data_reconhecimento", T.StringType(), True),
    T.StructField("observacoes", T.StringType(), True),
    T.StructField("matricula_cadastrante", T.StringType(), True),
    # 'tags' propositalmente não incluída (mesmo efeito do Table.RemoveColumns)
])
cols = [f.name for f in schema]
_numeric_cols = {"id", "visualizacoes", "votos"}

# ==========================
# 3) GET com retry/backoff
# ==========================
def http_get_with_retry(url: str, headers: Dict[str, str], timeout: int, max_retries: int = 5) -> requests.Response:
    backoff = 1.5
    attempt = 0
    while True:
        try:
            resp = requests.get(url, headers=headers, timeout=timeout)
            if resp.status_code in (429, 500, 502, 503, 504):
                attempt += 1
                if attempt > max_retries:
                    resp.raise_for_status()
                time.sleep(backoff ** attempt)
                continue
            resp.raise_for_status()
            return resp
        except requests.RequestException:
            attempt += 1
            if attempt > max_retries:
                raise
            time.sleep(backoff ** attempt)

# ==========================
# 4) Coleta paginada no Supabase
# ==========================
base_headers = {
    "apikey": API_KEY,
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "Accept": "application/json",
}

offset = 0
registros: List[Dict] = []

while True:
    headers = {**base_headers, "Range": f"{offset}-{offset + PAGE_SIZE - 1}"}
    resp = http_get_with_retry(SUPABASE_URL, headers, timeout=HTTP_TIMEOUT)
    batch = resp.json()
    if not batch:
        break
    registros.extend(batch)
    if len(batch) < PAGE_SIZE:
        break
    offset += PAGE_SIZE

print(f"Registros coletados do Supabase ({SUPABASE_TABLE}): {len(registros)}")

# ==========================
# 5) Monta DataFrame sem inferência
# ==========================
def _to_long(v):
    if v is None:
        return None
    try:
        # cobre int/float/str numérica
        return int(float(v)) if isinstance(v, str) and v.strip() != "" and ("." in v or "e" in v.lower()) else int(v)
    except Exception:
        return None

if len(registros) == 0:
    df = spark.createDataFrame([], schema)
else:
    rows = []
    for rec in registros:
        fixed = {}
        for c in cols:
            val = rec.get(c)
            if c in _numeric_cols:
                fixed[c] = _to_long(val)
            else:
                fixed[c] = None if val is None else str(val)
        rows.append(Row(**fixed))
    df = spark.createDataFrame(rows, schema)

df.printSchema()
df.show(10, truncate=False)

# ==========================
# 6) Escrita em Delta
# ==========================
if tabela_destino.strip():
    spark.sql(f"DROP TABLE IF EXISTS {tabela_destino}")
    df.write.format("delta").mode("overwrite").saveAsTable(tabela_destino)
    print(f"Tabela gerenciada gravada: {tabela_destino}")
else:
    df.write.format("delta").mode("overwrite").save(path_destino)
    print(f"Delta gravado no caminho: {path_destino}")

print(f"Linhas salvas: {df.count()}")
# Out:
# StatementMeta(, 4078c993-4e0e-4324-bc5c-52d410cc9191, 3, Finished, Available, Finished)
# Registros coletados do Supabase (tb_kaizen_cadastro): 233
# root
#  |-- id: long (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- objetivo: string (nullable = true)
#  |-- area_aplicada: string (nullable = true)
#  |-- data: string (nullable = true)
#  |-- pilar: string (nullable = true)
#  |-- elimina_desperdicio: string (nullable = true)
#  |-- modificado_por: string (nullable = true)
#  |-- modificado_quando: string (nullable = true)
#  |-- contrato_user: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- relevancia: string (nullable = true)
#  |-- uuidcadastro: string (nullable = true)
#  |-- resultados: string (nullable = true)
#  |-- geral: string (nullable = true)
#  |-- responsavel_etapa: string (nullable = true)
#  |-- visualizacoes: long (nullable = true)
#  |-- votos: long (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- titulo: string (nullable = true)
#  |-- descricao: string (nullable = true)
#  |-- etapa_processo: string (nullable = true)
#  |-- fabricou_dispositivo: string (nullable = true)
#  |-- projeto: string (nullable = true)
#  |-- nota_local: string (nullable = true)
#  |-- nota_corporativo: string (nullable = true)
#  |-- premiada: string (nullable = true)
#  |-- reconhecida: string (nullable = true)
#  |-- data_reconhecimento: string (nullable = true)
#  |-- observacoes: string (nullable = true)
#  |-- matricula_cadastrante: string (nullable = true)
#
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+-------------------+----------------+--------------------+-----------------------------------+-----------------------+-------------+-----------------------+----------+------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------------+-------------+-----+--------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+--------------------+--------------------------------------------------------------------------------------------------------------+----------+----------------+--------+-----------+-------------------+-----------+---------------------+
# |id |created_at                      |objetivo                                                                                                                                                                                                                                                                                                                                                                                                                              |area_aplicada                          |data               |pilar           |elimina_desperdicio |modificado_por                     |modificado_quando      |contrato_user|status                 |relevancia|uuidcadastro                        |resultados                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |geral|responsavel_etapa|visualizacoes|votos|categoria           |titulo                                                                                    |descricao                                                                                                                                                                                                                                                                                                                |etapa_processo   |fabricou_dispositivo|projeto                                                                                                       |nota_local|nota_corporativo|premiada|reconhecida|data_reconhecimento|observacoes|matricula_cadastrante|
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+-------------------+----------------+--------------------+-----------------------------------+-----------------------+-------------+-----------------------+----------+------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------------+-------------+-----+--------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+--------------------+--------------------------------------------------------------------------------------------------------------+----------+----------------+--------+-----------+-------------------+-----------+---------------------+
# |430|2025-08-20T19:23:37.102625+00:00|Garantir a segurança dos colaboradores reduzindo os riscos de acidentes entre pessoas e veículos na área do Granulador de Escória 01 além de otimizar o fluxo operacional ao separar o trajeto seguro das áreas de manobra dos caminhões proporcionando um acesso direto e mais protegido ao PVU                                                                                                                                      |Granulador de Escoria 01  Alto Forno 01|2025-06-17T00:00:00|Segurança       |Riscos              |RUTH MARQUES MOACYR                |2025-08-20T16:23:36.954|2078D        |Concluído              |4         |e12f31fe-e988-46e4-a1e9-c72f1c27af09|Redução significativa dos riscos de acidentes entre pedestres e veículos na área do Granulador de Escória 01 resultando em um ambiente de trabalho mais seguro para os colaboradores Além disso observouse uma otimização no fluxo operacional com menor interferência entre caminhões e pessoas proporcionando maior eficiência na circulação interna e garantindo acesso direto e protegido ao PVU Essa melhoria também contribuiu para uma melhor organização do espaço e para uma gestão mais eficaz dos riscos operacionais|NULL |                 |0            |0    |Contratos e projetos|Implantação de novo caminho seguro de acesso entre o Granulador de Escória 01 e 02 no AF01|Devido ao intenso fluxo de pessoas e caminhões na área do Granulador de Escória 01 foi realizada a realocação do caminho seguro que anteriormente se encontrava próximo ao local de manobra dos caminhões O novo trajeto agora passa pelo interior da unidade com acesso direto ao PVU                                   |Aguard. Avaliação|Não                 |                                                                                                              |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |131963               |
# |211|2024-12-19T14:04:35.759929+00:00|Eliminar o risco de queda por quebra ou avaria dos acessórios de elevação do malão.                                                                                                                                                                                                                                                                                                                                                   |Campanha dos convertedores / Aciaria   |2024-12-08T00:00:00|Segurança       |Riscos              |CHRISTIANY BUZATTO DOS SANTOS      |2025-01-16T10:13:15.689|2002D ACIARIA|Aguard. votação anual  |5         |575164fa-108d-45aa-823f-bbeaea68cc36|Eliminação do risco de queda devida a geometria dos olhais. Redução do custo na troca dos acessórios de içamento, sendo realizada se necessário após a inspeção periódica.                                                                                                                                                                                                                                                                                                                                                      |True |QSSMA            |0            |0    |Contratos e projetos|Fabricação de olhais de içamento no malão                                                 |Substituição das alças por olhais de içamento e a utilização de manilhas para garantir a integridade dos equipamentos de içamento.                                                                                                                                                                                       |NULL             |NULL                |NULL                                                                                                          |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |NULL                 |
# |320|2025-03-31T20:04:27.866941+00:00|Elimina o risco de chicoteamento das mangueiras pneumaticas durante a operação da maquina BMR100                                                                                                                                                                                                                                                                                                                                      |ALTO FORNO                             |2025-03-03T00:00:00|Segurança       |Riscos              |FRANCISCO SAVIO ALMEIDA DA SILVA   |2025-03-31T17:05:31.535|2076D        |Aguard. votação anual  |5         |b004a5cb-fcd5-4d94-9a89-ac8d8cc09c97|Segurança durante a operação da maquina evitando chicoteamento                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |True |QSSMA            |0            |0    |Contratos e projetos|Dipositivo de proteção contra chicoteamento do sistema pneumatito da maquina BMR1000      |Foi implantado uma grade metálica na região do sistema pneumático que alimenta o painel de comando da BMR1000 Dessa forma eliminamos o risco das mangueiras atingir o operador                                                                                                                                           |Aguard. Avaliação|Sim                 |https://jewtbymqxxubjpwnjtux.supabase.co/storage/v1/object/public/Systemmax/kaizenProjeto/1743451241630000.pdf|292       |NULL            |NULL    |NULL       |NULL               |NULL       |123519               |
# |330|2025-04-01T01:18:21.906464+00:00|Agilidade na inspeção de grande quantidade de extintoresA distância entre extintores e locais de difícil acesso é feita apenas em oportunidades necessárias sem retrabalhoMaior confiabilidade das informações por causa da captação online das informações Impossibilidade de omissão de algum item de inspeçãoRapidez na conclusão da inspeção 4 minutosZero consumo de papelAlém de baixo consumo de tempo digitando as informações|Toda área Operacional e Administrativa |2025-01-02T00:00:00|Processos       |Eficácia operacional|ALBERTO RIBEIRO DA COSTA           |2025-03-31T23:46:07.649|2071D        |Concluído              |5         |85be1751-f51d-4165-bb47-bddabe5d53b6|Teremos vantagens como Agilidade na inspeção de grande quantidade de extintores A distância entre extintores e locais de difícil acesso é feita apenas em oportunidades necessárias sem retrabalho Maior confiabilidade das informações por causa da captação online das informações Impossibilidade de omissão de algum item de inspeção Rapidez na conclusão da inspeção 4 minutos Zero consumo de papel Além de baixo consumo de tempo digitando as informações                                                              |NULL |                 |0            |0    |Contratos e projetos|Inspeção digital e online de extintores de incêndio                                       |Inspeção Digital e Online de Extintores de IncêndioSerá disponibilizado para os colaboradores destinados a inspecionar salvarem em seu celular o Link de acesso à Inspeção Online de Extintores de IncêndiohttpsformsofficecomrntnzR2BfRk Link de Acesso à Inspeção Online de Extintores de Incêndio  Reframax Engenharia|Aguard. Avaliação|Não                 |                                                                                                              |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |126990               |
# |286|2025-02-12T17:14:58.591418+00:00|O Projeto Saúde Mobilização tem o proposito de auxiliar e incentivar na melhoria de saúde e bem estar de todos os participantes do setor de mobilização.                                                                                                                                                                                                                                                                              |Mobilização de Pessoal                 |2025-01-07T00:00:00|Pessoas         |Qualidade de vida   |FELIPE VON DOLLINGER NORONHA GOMES |2025-02-12T14:14:58.432|0010A        |Aguard. votação anual  |2         |b58de2fb-62e3-4fa5-9d4b-f9f2ca8c2f6b|Meta prevista para ser alcançada em julho de 2025.                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |True |QSSMA            |0            |0    |Sede / Santa Luzia  |Projeto Saúde Mobilização                                                                 |Auxiliar e incentivar na melhoria de saúde e bem estar de todos os participantes do setor de mobilização. Foram realizadas bioimpedâncias em janeiro e existem metas a serem alcançados até julho.                                                                                                                       |NULL             |NULL                |NULL                                                                                                          |559       |NULL            |NULL    |NULL       |NULL               |NULL       |NULL                 |
# |210|2024-12-11T19:56:12.742684+00:00|A implementao do Systemmax teve como objetivo principal transformar a gesto de segurana e qualidade por meio da digitalizao de processos eliminando prticas antiquadas baseadas em papel                                                                                                                                                                                                                                              |Coorporativo                           |2023-03-10T00:00:00|Segurança       |Riscos              |GARIBALDI ALVES DA COSTA NETO      |2025-03-18T09:45:58.93 |0010A        |Concluído              |5         |2e42d881-90ca-41d7-934c-5e0d36123ae4|Resultados Alcanados Reduo de custos com insumos papel impresses e logstica de formulrios Contribuio para a preservao ambiental com a eliminao do uso de papel nos processos Agilidade na identificao e mitigao de riscos melhorando os ndices de segurana no trabalho                                                                                                                                                                                                                                                          |False|QSSMA            |0            |0    |Sede / Santa Luzia  |Systemmax                                                                                 |Criao de sistema para gesto de segurana e qualidade como cadastro e tratamento de desvios gesto das boas prticas etc                                                                                                                                                                                                     |Aguard. Avaliação|null                |                                                                                                              |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |NULL                 |
# |111|2024-10-29T18:30:34.368312+00:00|Eliminar o risco de queda dos colaboradores ao acessar os canais de corrida que estão em manutenção.                                                                                                                                                                                                                                                                                                                                  |Alto Forno                             |2023-11-08T00:00:00|Segurança       |Riscos              |LEANDRO LINS GOMES                 |2024-12-04T10:38:52.285|2076D        |Concluído              |2         |3a9fb404-f5b7-4eee-93f4-6849421bee24|Eliminado o risco de queda dos colaboradores ao acessar canal de corrida.                                                                                                                                                                                                                                                                                                                                                                                                                                                       |False|QSSMA            |0            |0    |Contratos e projetos|Plataforma para acesso a canais de corrida                                                |Plataforma para acesso a canais de corrida em manutenção, reduzindo o risco de queda ao acessar o canal                                                                                                                                                                                                                  |NULL             |NULL                |NULL                                                                                                          |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |NULL                 |
# |206|2024-12-06T13:27:14.549616+00:00|Fabricação de suporte para sustentação de bag durante carregamento de rebote nos RHs                                                                                                                                                                                                                                                                                                                                                  |RH's                                   |2024-08-03T00:00:00|Sustentabilidade|Eficácia operacional|CHRISTIANY BUZATTO DOS SANTOS      |2025-01-16T10:14:25.323|2002D ACIARIA|Concluído              |3         |fcb7c1c1-7c85-427f-ae3f-239fb52b7f2f| Foi gerada uma economia de material, consequentemente nos custos do processo, há que se dizer do quesito sustentabilidade, tendo em vista que o material coletado pelo dispositivo, seria descartado, reduzindo o desperdício e minimizando o descarte de resíduos                                                                                                                                                                                                                                                             |False|QSSMA            |0            |0    |Contratos e projetos|Fabricação de dispositivo para coleta e aproveitamento de material rebote nos fornos LD   |Dispositivo criado para facilitar a coleta do material rebote oriundo da projeção a quente dos RHs, posteriormente, o material coletado é lançado nos fornos LDs, gerando uma camada de projeção da sola, estendendo a vida útil do refratário.                                                                          |NULL             |NULL                |NULL                                                                                                          |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |NULL                 |
# |337|2025-06-10T14:12:01.770569+00:00|Foi eleiminado o risco do colaborador de prensamentos das maos e torção dos pes durante toda a atividade de manutenção no carro                                                                                                                                                                                                                                                                                                       |Aciaria                                |2025-06-09T00:00:00|Segurança       |Riscos              |ALEXSANDRO MARTINS DE CARVALHO     |2025-06-10T11:12:02.018|2077D        |Aguard. Avaliação Sesmt|1         |18d6f9ee-8808-441c-baaf-ed327c92884b|Mais segurança para os colaboradores durante a atividade de manutenção do vaso Rh2                                                                                                                                                                                                                                                                                                                                                                                                                                              |NULL |SESMT            |0            |0    |Contratos e projetos|Boa pratica melhoria no piso carro de manuteção RH2                                       |Foi realizado a troca do piso danificado do carro de manutenção de troca das pernas do RH2                                                                                                                                                                                                                               |Aguard. Avaliação|Não                 |                                                                                                              |NULL      |NULL            |NULL    |NULL       |NULL               |NULL       |127516               |
# |310|2025-03-27T14:49:34.823763+00:00|Tornar o processo de içamento de equipamentos mais seguro evitando o risco de que o dispositivo de içamento se solte de forma acidental com maior confiabilidade e através de acessórios normatizados                                                                                                                                                                                                                                 |Equipamentos                           |2025-02-07T00:00:00|Segurança       |Riscos              |DOUGLAS HENRIQUES DE FREITAS SANTOS|2025-03-27T11:49:34.658|0020A        |Concluído              |5         |2c8824dc-5323-4c28-b1fc-874f7ce6daee|Através da padronização dos ganchos soldáveis foi possível realizar a movimentação dos equipamentos com maior qualidade e segurança uma vez que este acessório é fabricado conforme norma através de materiais de alta resistencia possui trava de segurança com engate rápido e permite o içamento em ângulo para maior praticidade                                                                                                                                                                                            |NULL |SESMT            |0            |0    |Sede / Santa Luzia  |Padronização de ganchos de içamento                                                       |Padronização de acessório de içamento normatizado para equipamentos fabricados e adequados conforme NR12 que passam pelo setor de Equipamentos na unidade Santa Luzia                                                                                                                                                    |Aguard. Avaliação|Sim                 |https://jewtbymqxxubjpwnjtux.supabase.co/storage/v1/object/public/Systemmax/kaizenProjeto/1743086362334000.png|138       |NULL            |NULL    |NULL       |NULL               |NULL       |134026               |
# +---+--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+-------------------+----------------+--------------------+-----------------------------------+-----------------------+-------------+-----------------------+----------+------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------------+-------------+-----+--------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+--------------------+--------------------------------------------------------------------------------------------------------------+----------+----------------+--------+-----------+-------------------+-----------+---------------------+
# only showing top 10 rows
#
# Delta gravado no caminho: abfss://ws_sistemas@onelake.dfs.fabric.microsoft.com/lk_systemmax.Lakehouse/Tables/tab_boas_praticas
# Linhas salvas: 233
